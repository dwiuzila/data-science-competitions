# %%
# import packages

import numpy as np
import pandas as pd
from datetime import datetime, date, timedelta
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import gc    # garbage collector
import warnings

warnings.filterwarnings('ignore')    # ignore warning

# %%
# read files

df_train = pd.read_csv(
    'data/favorita-grocery-sales-train.csv', usecols=[1, 2, 3, 4, 5],
    dtype={'onpromotion': bool},
    converters={'unit_sales': lambda u: np.log1p(
        float(u)) if float(u) > 0 else 0},
    parse_dates=["date"],
    skiprows=range(1, 66458909)  # 2016-01-01
)

df_test = pd.read_csv(
    "data/favorita-grocery-sales-test.csv", usecols=[0, 1, 2, 3, 4],
    dtype={'onpromotion': bool},
    parse_dates=["date"]  # , date_parser=parser
).set_index(
    ['store_nbr', 'item_nbr', 'date']
)

items = pd.read_csv(
    "data/favorita-grocery-sales-items.csv",
).set_index("item_nbr")

stores = pd.read_csv(
    "data/favorita-grocery-sales-stores.csv",
).set_index("store_nbr")

# %%
# sneak peek

print(df_train.info(), end='\n\n')
print(df_test.info(), end='\n\n')
print(items.info(), end='\n\n')
print(stores.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59038132 entries, 0 to 59038131
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   date         datetime64[ns]
#  1   store_nbr    int64
#  2   item_nbr     int64
#  3   unit_sales   float64
#  4   onpromotion  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2)
# memory usage: 1.8 GB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3370464 entries, (1, 96995, Timestamp('2017-08-16 00:00:00')) to (54, 2134244, Timestamp('2017-08-31 00:00:00'))
# Data columns (total 2 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   onpromotion  bool
# dtypes: bool(1), int64(1)
# memory usage: 41.9 MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4100 entries, 96995 to 2134244
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   family      4100 non-null   object
#  1   class       4100 non-null   int64
#  2   perishable  4100 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 128.1+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 1 to 54
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   city     54 non-null     object
#  1   state    54 non-null     object
#  2   type     54 non-null     object
#  3   cluster  54 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.1+ KB
# None

# %%
df_train.head()
# Out:
#         date  store_nbr  item_nbr  unit_sales  onpromotion
# 0 2016-01-01         25    105574    2.564949        False
# 1 2016-01-01         25    105575    2.302585        False
# 2 2016-01-01         25    105857    1.386294        False
# 3 2016-01-01         25    108634    1.386294        False
# 4 2016-01-01         25    108701    1.098612         True

# %%
df_test.head()
# Out:
#                                       id  onpromotion
# store_nbr item_nbr date
# 1         96995    2017-08-16  125497040        False
#           99197    2017-08-16  125497041        False
#           103501   2017-08-16  125497042        False
#           103520   2017-08-16  125497043        False
#           103665   2017-08-16  125497044        False

# %%
items.head()
# Out:
#                 family  class  perishable
# item_nbr
# 96995        GROCERY I   1093           0
# 99197        GROCERY I   1067           0
# 103501        CLEANING   3008           0
# 103520       GROCERY I   1028           0
# 103665    BREAD/BAKERY   2712           1

# %%
stores.head()
# Out:
#                     city                           state type  cluster
# store_nbr
# 1                  Quito                       Pichincha    D       13
# 2                  Quito                       Pichincha    D       13
# 3                  Quito                       Pichincha    D        8
# 4                  Quito                       Pichincha    D        9
# 5          Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
# data cleaning

le = LabelEncoder()
items['family'] = le.fit_transform(items['family'].values)

stores['city'] = le.fit_transform(stores['city'].values)
stores['state'] = le.fit_transform(stores['state'].values)
stores['type'] = le.fit_transform(stores['type'].values)

df_2017 = df_train.loc[df_train.date >= datetime(2017,1,1)]
del df_train

promo_2017_train = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack(
        level=-1).fillna(False)
promo_2017_train.columns = promo_2017_train.columns.get_level_values(1)
promo_2017_test = df_test[["onpromotion"]].unstack(level=-1).fillna(False)
promo_2017_test.columns = promo_2017_test.columns.get_level_values(1)
promo_2017_test = promo_2017_test.reindex(promo_2017_train.index).fillna(False)
promo_2017 = pd.concat([promo_2017_train, promo_2017_test], axis=1)
del promo_2017_test, promo_2017_train

df_2017 = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["unit_sales"]].unstack(
        level=-1).fillna(0)
df_2017.columns = df_2017.columns.get_level_values(1)

items = items.reindex(df_2017.index.get_level_values(1))
stores = stores.reindex(df_2017.index.get_level_values(0))


df_2017_item = df_2017.groupby('item_nbr')[df_2017.columns].sum()
promo_2017_item = promo_2017.groupby('item_nbr')[promo_2017.columns].sum()

df_2017_store_class = df_2017.reset_index()
df_2017_store_class['class'] = items['class'].values
df_2017_store_class_index = df_2017_store_class[['class', 'store_nbr']]
df_2017_store_class = df_2017_store_class.groupby(['class', 'store_nbr'])[df_2017.columns].sum()

df_2017_promo_store_class = promo_2017.reset_index()
df_2017_promo_store_class['class'] = items['class'].values
df_2017_promo_store_class_index = df_2017_promo_store_class[['class', 'store_nbr']]
df_2017_promo_store_class = df_2017_promo_store_class.groupby(['class', 'store_nbr'])[promo_2017.columns].sum()

# %%
# a function for preprocessing

def get_timespan(df, dt, minus, periods, freq='D'):
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

def prepare_dataset(df, promo_df, t2017, is_train=True, name_prefix=None):
    X = {
        "promo_14_2017": get_timespan(promo_df, t2017, 14, 14).sum(axis=1).values,
        "promo_60_2017": get_timespan(promo_df, t2017, 60, 60).sum(axis=1).values,
        "promo_140_2017": get_timespan(promo_df, t2017, 140, 140).sum(axis=1).values,
        "promo_3_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 3).sum(axis=1).values,
        "promo_7_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 7).sum(axis=1).values,
        "promo_14_2017_aft": get_timespan(promo_df, t2017 + timedelta(days=16), 15, 14).sum(axis=1).values,
    }

    for i in [3, 7, 14, 30, 60, 140]:
        tmp1 = get_timespan(df, t2017, i, i)
        tmp2 = (get_timespan(promo_df, t2017, i, i) > 0) * 1

        X['has_promo_mean_%s' % i] = (tmp1 * tmp2.replace(0, np.nan)).mean(axis=1).values
        X['has_promo_mean_%s_decay' % i] = (tmp1 * tmp2.replace(0, np.nan) * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values

        X['no_promo_mean_%s' % i] = (tmp1 * (1 - tmp2).replace(0, np.nan)).mean(axis=1).values
        X['no_promo_mean_%s_decay' % i] = (tmp1 * (1 - tmp2).replace(0, np.nan) * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values

    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)
        X['diff_%s_mean' % i] = tmp.diff(axis=1).mean(axis=1).values
        X['mean_%s_decay' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values
        X['mean_%s' % i] = tmp.mean(axis=1).values
        X['median_%s' % i] = tmp.median(axis=1).values
        X['min_%s' % i] = tmp.min(axis=1).values
        X['max_%s' % i] = tmp.max(axis=1).values
        X['std_%s' % i] = tmp.std(axis=1).values

    for i in [3, 7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017 + timedelta(days=-7), i, i)
        X['diff_%s_mean_2' % i] = tmp.diff(axis=1).mean(axis=1).values
        X['mean_%s_decay_2' % i] = (tmp * np.power(0.9, np.arange(i)[::-1])).sum(axis=1).values
        X['mean_%s_2' % i] = tmp.mean(axis=1).values
        X['median_%s_2' % i] = tmp.median(axis=1).values
        X['min_%s_2' % i] = tmp.min(axis=1).values
        X['max_%s_2' % i] = tmp.max(axis=1).values
        X['std_%s_2' % i] = tmp.std(axis=1).values

    for i in [7, 14, 30, 60, 140]:
        tmp = get_timespan(df, t2017, i, i)
        X['has_sales_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values
        X['last_has_sales_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values
        X['first_has_sales_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values

        tmp = get_timespan(promo_df, t2017, i, i)
        X['has_promo_days_in_last_%s' % i] = (tmp > 0).sum(axis=1).values
        X['last_has_promo_day_in_last_%s' % i] = i - ((tmp > 0) * np.arange(i)).max(axis=1).values
        X['first_has_promo_day_in_last_%s' % i] = ((tmp > 0) * np.arange(i, 0, -1)).max(axis=1).values

    tmp = get_timespan(promo_df, t2017 + timedelta(days=16), 15, 15)
    X['has_promo_days_in_after_15_days'] = (tmp > 0).sum(axis=1).values
    X['last_has_promo_day_in_after_15_days'] = i - ((tmp > 0) * np.arange(15)).max(axis=1).values
    X['first_has_promo_day_in_after_15_days'] = ((tmp > 0) * np.arange(15, 0, -1)).max(axis=1).values

    for i in range(1, 16):
        X['day_%s_2017' % i] = get_timespan(df, t2017, i, 1).values.ravel()

    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(df, t2017, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(df, t2017, 140-i, 20, freq='7D').mean(axis=1).values

    for i in range(-16, 16):
        X["promo_{}".format(i)] = promo_df[str(t2017 + timedelta(days=i))].values.astype(np.uint8)

    X = pd.DataFrame(X)

    if is_train:
        y = df[
            pd.date_range(t2017, periods=16)
        ].values
        return X, y
    if name_prefix is not None:
        X.columns = ['%s_%s' % (name_prefix, c) for c in X.columns]
    return X

# %%
# data preprocessing

print("Preparing dataset...")
t2017 = date(2017, 6, 14)
num_days = 6
X_l, y_l = [], []
for i in range(num_days):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(df_2017, promo_2017, t2017 + delta)

    X_tmp2 = prepare_dataset(df_2017_item, promo_2017_item, t2017 + delta, is_train=False, name_prefix='item')
    X_tmp2.index = df_2017_item.index
    X_tmp2 = X_tmp2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

    X_tmp3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, t2017 + delta, is_train=False, name_prefix='store_class')
    X_tmp3.index = df_2017_store_class.index
    X_tmp3 = X_tmp3.reindex(axis=df_2017_store_class_index).reset_index(drop=True)

    X_tmp = pd.concat([X_tmp, X_tmp2, X_tmp3, items.reset_index(), stores.reset_index()], axis=1)
    X_l.append(X_tmp)
    y_l.append(y_tmp)

    del X_tmp2
    gc.collect()

X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)

del X_l, y_l
X_val, y_val = prepare_dataset(df_2017, promo_2017, date(2017, 7, 26))

X_val2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 7, 26), is_train=False, name_prefix='item')
X_val2.index = df_2017_item.index
X_val2 = X_val2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_val3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, date(2017, 7, 26), is_train=False, name_prefix='store_class')
X_val3.index = df_2017_store_class.index
X_val3 = X_val3.reindex(axis=df_2017_store_class_index).reset_index(drop=True)

X_val = pd.concat([X_val, X_val2, X_val3, items.reset_index(), stores.reset_index()], axis=1)

X_test = prepare_dataset(df_2017, promo_2017, date(2017, 8, 16), is_train=False)

X_test2 = prepare_dataset(df_2017_item, promo_2017_item, date(2017, 8, 16), is_train=False, name_prefix='item')
X_test2.index = df_2017_item.index
X_test2 = X_test2.reindex(df_2017.index.get_level_values(1)).reset_index(drop=True)

X_test3 = prepare_dataset(df_2017_store_class, df_2017_promo_store_class, date(2017, 8, 16), is_train=False, name_prefix='store_class')
X_test3.index = df_2017_store_class.index
X_test3 = X_test3.reindex(axis=df_2017_store_class_index).reset_index(drop=True)

X_test = pd.concat([X_test, X_test2, X_test3, items.reset_index(), stores.reset_index()], axis=1)

del X_test2, X_val2, df_2017_item, promo_2017_item, df_2017_store_class, df_2017_promo_store_class, df_2017_store_class_index
gc.collect()
# Out:
# Preparing dataset...
# 0

# %%
# make a list of data chunk for each X_train & y_train

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape)

n = X_val.shape[0]

list_X_train = [X_train[i : i+n] for i in range(0, X_train.shape[0], n)]
list_y_train = [y_train[i : i+n] for i in range(0, y_train.shape[0], n)]
# Out:
# (1005090, 633) (1005090, 16)
# (167515, 633) (167515, 16)
# (167515, 633)

# %%
# train & predict

print("Training and predicting models...")
params = {
    'num_leaves': 80,
    'objective': 'regression',
    'min_data_in_leaf': 200,
    'learning_rate': 0.02,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.7,
    'bagging_freq': 1,
    'metric': 'l2',
    'num_threads': 2,
    'verbose': -1
}

MAX_ROUNDS = 5000
val_pred = []
test_pred = []
cate_vars = []
for i in range(16):
    print("\n" + "=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    
    bst = None
    for X_train_chunk, y_train_chunk in zip(list_X_train, list_y_train):
        dtrain = lgb.Dataset(
            X_train_chunk, label=y_train_chunk[:, i],
            categorical_feature=cate_vars,
            weight=items["perishable"] * 0.25 + 1
        )
        dval = lgb.Dataset(
            X_val, label=y_val[:, i], reference=dtrain,
            weight=items["perishable"] * 0.25 + 1,
            categorical_feature=cate_vars)

        bst = lgb.train(
            params, dtrain, num_boost_round=MAX_ROUNDS, init_model=bst, keep_training_booster=True,
            valid_sets=[dtrain, dval], early_stopping_rounds=125, verbose_eval=50
        )
    
    val_pred.append(bst.predict(X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))
# Out:
# Training and predicting models...
#
# ==================================================
# Step 1
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.415819	valid_1's l2: 0.406823
# [100]	training's l2: 0.310791	valid_1's l2: 0.310133
# [150]	training's l2: 0.288704	valid_1's l2: 0.29398
# [200]	training's l2: 0.279292	valid_1's l2: 0.289951
# [250]	training's l2: 0.272803	valid_1's l2: 0.288225
# [300]	training's l2: 0.267978	valid_1's l2: 0.287679
# [350]	training's l2: 0.263767	valid_1's l2: 0.287434
# [400]	training's l2: 0.259897	valid_1's l2: 0.287217
# [450]	training's l2: 0.256266	valid_1's l2: 0.287157
# [500]	training's l2: 0.252881	valid_1's l2: 0.287117
# [550]	training's l2: 0.249609	valid_1's l2: 0.287113
# [600]	training's l2: 0.246432	valid_1's l2: 0.286988
# [650]	training's l2: 0.243448	valid_1's l2: 0.287049
# [700]	training's l2: 0.240553	valid_1's l2: 0.287129
# Early stopping, best iteration is:
# [590]	training's l2: 0.247061	valid_1's l2: 0.286979
# Training until validation scores don't improve for 125 rounds
# [750]	training's l2: 0.282968	valid_1's l2: 0.286247
# [800]	training's l2: 0.27695	valid_1's l2: 0.286105
# [850]	training's l2: 0.272034	valid_1's l2: 0.286167
# [900]	training's l2: 0.267727	valid_1's l2: 0.28616
# Early stopping, best iteration is:
# [801]	training's l2: 0.276844	valid_1's l2: 0.286102
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.281865	valid_1's l2: 0.285707
# [1000]	training's l2: 0.276079	valid_1's l2: 0.285353
# [1050]	training's l2: 0.271354	valid_1's l2: 0.285321
# [1100]	training's l2: 0.267178	valid_1's l2: 0.285361
# [1150]	training's l2: 0.263324	valid_1's l2: 0.285385
# [1200]	training's l2: 0.25968	valid_1's l2: 0.285498
# Early stopping, best iteration is:
# [1086]	training's l2: 0.268286	valid_1's l2: 0.285307
# Training until validation scores don't improve for 125 rounds
# [1250]	training's l2: 0.292564	valid_1's l2: 0.28543
# [1300]	training's l2: 0.28522	valid_1's l2: 0.286581
# [1350]	training's l2: 0.279738	valid_1's l2: 0.287083
# Early stopping, best iteration is:
# [1228]	training's l2: 0.297813	valid_1's l2: 0.285048
# Training until validation scores don't improve for 125 rounds
# [1400]	training's l2: 0.280031	valid_1's l2: 0.285407
# [1450]	training's l2: 0.274964	valid_1's l2: 0.284959
# [1500]	training's l2: 0.270588	valid_1's l2: 0.284818
# [1550]	training's l2: 0.266594	valid_1's l2: 0.284727
# [1600]	training's l2: 0.262896	valid_1's l2: 0.284791
# [1650]	training's l2: 0.259333	valid_1's l2: 0.284845
# Early stopping, best iteration is:
# [1554]	training's l2: 0.266325	valid_1's l2: 0.28472
# Training until validation scores don't improve for 125 rounds
# [1700]	training's l2: 0.284143	valid_1's l2: 0.284748
# [1750]	training's l2: 0.278813	valid_1's l2: 0.284795
# [1800]	training's l2: 0.274328	valid_1's l2: 0.284805
# [1850]	training's l2: 0.270277	valid_1's l2: 0.284796
# Early stopping, best iteration is:
# [1725]	training's l2: 0.281309	valid_1's l2: 0.284678
#
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.416886	valid_1's l2: 0.421703
# [100]	training's l2: 0.328053	valid_1's l2: 0.340823
# [150]	training's l2: 0.308272	valid_1's l2: 0.327383
# [200]	training's l2: 0.299109	valid_1's l2: 0.323853
# [250]	training's l2: 0.292449	valid_1's l2: 0.322359
# [300]	training's l2: 0.286989	valid_1's l2: 0.321551
# [350]	training's l2: 0.282331	valid_1's l2: 0.321164
# [400]	training's l2: 0.27806	valid_1's l2: 0.320816
# [450]	training's l2: 0.274153	valid_1's l2: 0.320648
# [500]	training's l2: 0.270463	valid_1's l2: 0.320539
# [550]	training's l2: 0.266942	valid_1's l2: 0.320548
# [600]	training's l2: 0.263564	valid_1's l2: 0.32048
# [650]	training's l2: 0.260287	valid_1's l2: 0.320446
# [700]	training's l2: 0.257121	valid_1's l2: 0.32037
# [750]	training's l2: 0.254096	valid_1's l2: 0.320434
# [800]	training's l2: 0.251181	valid_1's l2: 0.32047
# Early stopping, best iteration is:
# [697]	training's l2: 0.257319	valid_1's l2: 0.320363
# Training until validation scores don't improve for 125 rounds
# [850]	training's l2: 0.309472	valid_1's l2: 0.319441
# [900]	training's l2: 0.300635	valid_1's l2: 0.319953
# [950]	training's l2: 0.294309	valid_1's l2: 0.320567
# Early stopping, best iteration is:
# [854]	training's l2: 0.308557	valid_1's l2: 0.319424
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.302762	valid_1's l2: 0.320184
# [1050]	training's l2: 0.29552	valid_1's l2: 0.319644
# [1100]	training's l2: 0.289623	valid_1's l2: 0.319536
# [1150]	training's l2: 0.284559	valid_1's l2: 0.319597
# [1200]	training's l2: 0.27995	valid_1's l2: 0.319705
# Early stopping, best iteration is:
# [1114]	training's l2: 0.288125	valid_1's l2: 0.31948
# Training until validation scores don't improve for 125 rounds
# [1250]	training's l2: 0.32084	valid_1's l2: 0.319327
# [1300]	training's l2: 0.31111	valid_1's l2: 0.318964
# [1350]	training's l2: 0.30442	valid_1's l2: 0.319
# [1400]	training's l2: 0.298908	valid_1's l2: 0.318879
# [1450]	training's l2: 0.294011	valid_1's l2: 0.318801
# [1500]	training's l2: 0.289507	valid_1's l2: 0.318734
# [1550]	training's l2: 0.285284	valid_1's l2: 0.31866
# [1600]	training's l2: 0.281316	valid_1's l2: 0.318669
# [1650]	training's l2: 0.277542	valid_1's l2: 0.318705
# Early stopping, best iteration is:
# [1555]	training's l2: 0.284874	valid_1's l2: 0.318638
# Training until validation scores don't improve for 125 rounds
# [1700]	training's l2: 0.312378	valid_1's l2: 0.317207
# [1750]	training's l2: 0.30411	valid_1's l2: 0.316376
# [1800]	training's l2: 0.298357	valid_1's l2: 0.316397
# [1850]	training's l2: 0.293332	valid_1's l2: 0.316252
# [1900]	training's l2: 0.288794	valid_1's l2: 0.316274
# [1950]	training's l2: 0.28451	valid_1's l2: 0.316317
# [2000]	training's l2: 0.28044	valid_1's l2: 0.316354
# Early stopping, best iteration is:
# [1891]	training's l2: 0.289574	valid_1's l2: 0.316248
# Training until validation scores don't improve for 125 rounds
# [2050]	training's l2: 0.306065	valid_1's l2: 0.315878
# [2100]	training's l2: 0.29882	valid_1's l2: 0.316802
# [2150]	training's l2: 0.293317	valid_1's l2: 0.317388
# Early stopping, best iteration is:
# [2039]	training's l2: 0.308262	valid_1's l2: 0.315781
#
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.446232	valid_1's l2: 0.453973
# [100]	training's l2: 0.336889	valid_1's l2: 0.356583
# [150]	training's l2: 0.312159	valid_1's l2: 0.340864
# [200]	training's l2: 0.300984	valid_1's l2: 0.337343
# [250]	training's l2: 0.293147	valid_1's l2: 0.336184
# [300]	training's l2: 0.287244	valid_1's l2: 0.335763
# [350]	training's l2: 0.282374	valid_1's l2: 0.335785
# [400]	training's l2: 0.277994	valid_1's l2: 0.335707
# [450]	training's l2: 0.273875	valid_1's l2: 0.335781
# [500]	training's l2: 0.270169	valid_1's l2: 0.335642
# [550]	training's l2: 0.266624	valid_1's l2: 0.335672
# [600]	training's l2: 0.26316	valid_1's l2: 0.335741
# [650]	training's l2: 0.259875	valid_1's l2: 0.335826
# Early stopping, best iteration is:
# [536]	training's l2: 0.267612	valid_1's l2: 0.335609
# Training until validation scores don't improve for 125 rounds
# [700]	training's l2: 0.309758	valid_1's l2: 0.336184
# [750]	training's l2: 0.300914	valid_1's l2: 0.337828
# Early stopping, best iteration is:
# [673]	training's l2: 0.318092	valid_1's l2: 0.335441
# Training until validation scores don't improve for 125 rounds
# [800]	training's l2: 0.30915	valid_1's l2: 0.33857
# [850]	training's l2: 0.298652	valid_1's l2: 0.335371
# [900]	training's l2: 0.291843	valid_1's l2: 0.334628
# [950]	training's l2: 0.286532	valid_1's l2: 0.334484
# [1000]	training's l2: 0.281913	valid_1's l2: 0.334394
# [1050]	training's l2: 0.277702	valid_1's l2: 0.334504
# [1100]	training's l2: 0.273693	valid_1's l2: 0.334632
# Early stopping, best iteration is:
# [1001]	training's l2: 0.281822	valid_1's l2: 0.334391
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.314101	valid_1's l2: 0.334335
# [1200]	training's l2: 0.305178	valid_1's l2: 0.333476
# [1250]	training's l2: 0.298887	valid_1's l2: 0.33319
# [1300]	training's l2: 0.29354	valid_1's l2: 0.333162
# [1350]	training's l2: 0.28875	valid_1's l2: 0.333162
# [1400]	training's l2: 0.284376	valid_1's l2: 0.333309
# Early stopping, best iteration is:
# [1320]	training's l2: 0.291574	valid_1's l2: 0.333078
# Training until validation scores don't improve for 125 rounds
# [1450]	training's l2: 0.315862	valid_1's l2: 0.332756
# [1500]	training's l2: 0.304958	valid_1's l2: 0.331357
# [1550]	training's l2: 0.298261	valid_1's l2: 0.331049
# [1600]	training's l2: 0.292825	valid_1's l2: 0.331043
# [1650]	training's l2: 0.288069	valid_1's l2: 0.330993
# [1700]	training's l2: 0.283741	valid_1's l2: 0.330932
# [1750]	training's l2: 0.279712	valid_1's l2: 0.330942
# [1800]	training's l2: 0.275964	valid_1's l2: 0.331003
# Early stopping, best iteration is:
# [1722]	training's l2: 0.281948	valid_1's l2: 0.330893
# Training until validation scores don't improve for 125 rounds
# [1850]	training's l2: 0.309825	valid_1's l2: 0.330823
# [1900]	training's l2: 0.301128	valid_1's l2: 0.329593
# [1950]	training's l2: 0.294996	valid_1's l2: 0.329455
# [2000]	training's l2: 0.289881	valid_1's l2: 0.329539
# [2050]	training's l2: 0.285285	valid_1's l2: 0.329768
# Early stopping, best iteration is:
# [1945]	training's l2: 0.295558	valid_1's l2: 0.329431
#
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.488565	valid_1's l2: 0.475683
# [100]	training's l2: 0.364225	valid_1's l2: 0.371959
# [150]	training's l2: 0.336344	valid_1's l2: 0.35704
# [200]	training's l2: 0.323898	valid_1's l2: 0.354366
# [250]	training's l2: 0.314631	valid_1's l2: 0.352713
# [300]	training's l2: 0.307595	valid_1's l2: 0.35217
# [350]	training's l2: 0.302031	valid_1's l2: 0.351767
# [400]	training's l2: 0.297185	valid_1's l2: 0.351592
# [450]	training's l2: 0.292801	valid_1's l2: 0.351515
# [500]	training's l2: 0.288633	valid_1's l2: 0.35144
# [550]	training's l2: 0.284676	valid_1's l2: 0.351386
# [600]	training's l2: 0.280974	valid_1's l2: 0.351354
# [650]	training's l2: 0.277502	valid_1's l2: 0.351413
# [700]	training's l2: 0.274183	valid_1's l2: 0.351503
# Early stopping, best iteration is:
# [593]	training's l2: 0.281447	valid_1's l2: 0.351339
# Training until validation scores don't improve for 125 rounds
# [750]	training's l2: 0.333018	valid_1's l2: 0.348307
# [800]	training's l2: 0.321249	valid_1's l2: 0.348853
# [850]	training's l2: 0.31352	valid_1's l2: 0.349821
# Early stopping, best iteration is:
# [755]	training's l2: 0.331504	valid_1's l2: 0.348199
# Training until validation scores don't improve for 125 rounds
# [900]	training's l2: 0.350462	valid_1's l2: 0.34651
# [950]	training's l2: 0.325362	valid_1's l2: 0.351648
# [1000]	training's l2: 0.315276	valid_1's l2: 0.355784
# Early stopping, best iteration is:
# [902]	training's l2: 0.348654	valid_1's l2: 0.34649
# Training until validation scores don't improve for 125 rounds
# [1050]	training's l2: 0.340456	valid_1's l2: 0.346919
# [1100]	training's l2: 0.322378	valid_1's l2: 0.344224
# [1150]	training's l2: 0.313748	valid_1's l2: 0.34537
# [1200]	training's l2: 0.307579	valid_1's l2: 0.34625
# Early stopping, best iteration is:
# [1089]	training's l2: 0.325059	valid_1's l2: 0.344037
# Training until validation scores don't improve for 125 rounds
# [1250]	training's l2: 0.323322	valid_1's l2: 0.343608
# [1300]	training's l2: 0.314553	valid_1's l2: 0.342878
# [1350]	training's l2: 0.308168	valid_1's l2: 0.342519
# [1400]	training's l2: 0.302782	valid_1's l2: 0.342433
# [1450]	training's l2: 0.297996	valid_1's l2: 0.34245
# [1500]	training's l2: 0.293625	valid_1's l2: 0.34248
# Early stopping, best iteration is:
# [1422]	training's l2: 0.300626	valid_1's l2: 0.342376
# Training until validation scores don't improve for 125 rounds
# [1550]	training's l2: 0.328853	valid_1's l2: 0.342562
# [1600]	training's l2: 0.318648	valid_1's l2: 0.343503
# [1650]	training's l2: 0.311088	valid_1's l2: 0.344293
# Early stopping, best iteration is:
# [1555]	training's l2: 0.327483	valid_1's l2: 0.342502
#
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.470677	valid_1's l2: 0.527993
# [100]	training's l2: 0.355708	valid_1's l2: 0.403378
# [150]	training's l2: 0.329196	valid_1's l2: 0.377731
# [200]	training's l2: 0.316735	valid_1's l2: 0.370618
# [250]	training's l2: 0.307666	valid_1's l2: 0.36706
# [300]	training's l2: 0.301045	valid_1's l2: 0.36555
# [350]	training's l2: 0.295573	valid_1's l2: 0.364956
# [400]	training's l2: 0.290887	valid_1's l2: 0.36472
# [450]	training's l2: 0.286622	valid_1's l2: 0.364883
# [500]	training's l2: 0.282631	valid_1's l2: 0.364693
# [550]	training's l2: 0.278816	valid_1's l2: 0.364438
# [600]	training's l2: 0.275207	valid_1's l2: 0.364423
# [650]	training's l2: 0.271832	valid_1's l2: 0.364543
# [700]	training's l2: 0.268503	valid_1's l2: 0.364601
# Early stopping, best iteration is:
# [578]	training's l2: 0.276789	valid_1's l2: 0.364374
# Training until validation scores don't improve for 125 rounds
# [750]	training's l2: 0.339509	valid_1's l2: 0.352584
# [800]	training's l2: 0.326161	valid_1's l2: 0.350754
# [850]	training's l2: 0.317399	valid_1's l2: 0.350892
# [900]	training's l2: 0.310447	valid_1's l2: 0.351124
# Early stopping, best iteration is:
# [815]	training's l2: 0.323238	valid_1's l2: 0.350628
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.37037	valid_1's l2: 0.349909
# [1000]	training's l2: 0.337648	valid_1's l2: 0.354782
# [1050]	training's l2: 0.325963	valid_1's l2: 0.359317
# Early stopping, best iteration is:
# [955]	training's l2: 0.364623	valid_1's l2: 0.349784
# Training until validation scores don't improve for 125 rounds
# [1100]	training's l2: 0.344803	valid_1's l2: 0.349785
# [1150]	training's l2: 0.32474	valid_1's l2: 0.343524
# [1200]	training's l2: 0.315578	valid_1's l2: 0.343364
# [1250]	training's l2: 0.309025	valid_1's l2: 0.343642
# Early stopping, best iteration is:
# [1171]	training's l2: 0.320309	valid_1's l2: 0.343202
# Training until validation scores don't improve for 125 rounds
# [1300]	training's l2: 0.342906	valid_1's l2: 0.343312
# [1350]	training's l2: 0.328111	valid_1's l2: 0.340215
# [1400]	training's l2: 0.319774	valid_1's l2: 0.340123
# [1450]	training's l2: 0.313423	valid_1's l2: 0.340264
# [1500]	training's l2: 0.308007	valid_1's l2: 0.340512
# Early stopping, best iteration is:
# [1377]	training's l2: 0.323228	valid_1's l2: 0.340041
# Training until validation scores don't improve for 125 rounds
# [1550]	training's l2: 0.321222	valid_1's l2: 0.343247
# [1600]	training's l2: 0.312508	valid_1's l2: 0.346091
# Early stopping, best iteration is:
# [1506]	training's l2: 0.335489	valid_1's l2: 0.340485
#
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.449357	valid_1's l2: 0.491487
# [100]	training's l2: 0.347994	valid_1's l2: 0.387748
# [150]	training's l2: 0.325318	valid_1's l2: 0.369028
# [200]	training's l2: 0.314478	valid_1's l2: 0.364382
# [250]	training's l2: 0.306297	valid_1's l2: 0.362793
# [300]	training's l2: 0.300036	valid_1's l2: 0.362182
# [350]	training's l2: 0.2949	valid_1's l2: 0.362037
# [400]	training's l2: 0.290357	valid_1's l2: 0.362089
# [450]	training's l2: 0.286119	valid_1's l2: 0.362228
# Early stopping, best iteration is:
# [367]	training's l2: 0.293351	valid_1's l2: 0.362005
# Training until validation scores don't improve for 125 rounds
# [500]	training's l2: 0.344178	valid_1's l2: 0.362654
# [550]	training's l2: 0.329492	valid_1's l2: 0.364954
# [600]	training's l2: 0.321124	valid_1's l2: 0.366858
# Early stopping, best iteration is:
# [493]	training's l2: 0.347796	valid_1's l2: 0.362473
# Training until validation scores don't improve for 125 rounds
# [650]	training's l2: 0.361201	valid_1's l2: 0.354952
# [700]	training's l2: 0.343752	valid_1's l2: 0.352563
# [750]	training's l2: 0.335012	valid_1's l2: 0.352824
# [800]	training's l2: 0.328485	valid_1's l2: 0.353201
# Early stopping, best iteration is:
# [695]	training's l2: 0.344922	valid_1's l2: 0.352526
# Training until validation scores don't improve for 125 rounds
# [850]	training's l2: 0.340005	valid_1's l2: 0.352149
# [900]	training's l2: 0.325987	valid_1's l2: 0.356254
# [950]	training's l2: 0.317932	valid_1's l2: 0.358687
# Early stopping, best iteration is:
# [837]	training's l2: 0.34683	valid_1's l2: 0.35168
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.334765	valid_1's l2: 0.3538
# [1050]	training's l2: 0.325714	valid_1's l2: 0.351887
# [1100]	training's l2: 0.319324	valid_1's l2: 0.35151
# [1150]	training's l2: 0.313699	valid_1's l2: 0.351549
# [1200]	training's l2: 0.308608	valid_1's l2: 0.351622
# Early stopping, best iteration is:
# [1109]	training's l2: 0.318304	valid_1's l2: 0.351494
# Training until validation scores don't improve for 125 rounds
# [1250]	training's l2: 0.344279	valid_1's l2: 0.350973
# [1300]	training's l2: 0.332563	valid_1's l2: 0.351158
# [1350]	training's l2: 0.324723	valid_1's l2: 0.352034
# Early stopping, best iteration is:
# [1263]	training's l2: 0.340448	valid_1's l2: 0.350745
#
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.447374	valid_1's l2: 0.549173
# [100]	training's l2: 0.345333	valid_1's l2: 0.43548
# [150]	training's l2: 0.322538	valid_1's l2: 0.413136
# [200]	training's l2: 0.311475	valid_1's l2: 0.407773
# [250]	training's l2: 0.303085	valid_1's l2: 0.407116
# [300]	training's l2: 0.297049	valid_1's l2: 0.4067
# [350]	training's l2: 0.292073	valid_1's l2: 0.406995
# [400]	training's l2: 0.287643	valid_1's l2: 0.407343
# Early stopping, best iteration is:
# [303]	training's l2: 0.296713	valid_1's l2: 0.406677
# Training until validation scores don't improve for 125 rounds
# [450]	training's l2: 0.326796	valid_1's l2: 0.416542
# [500]	training's l2: 0.314549	valid_1's l2: 0.429441
# [550]	training's l2: 0.306676	valid_1's l2: 0.436986
# Early stopping, best iteration is:
# [429]	training's l2: 0.335767	valid_1's l2: 0.407808
# Training until validation scores don't improve for 125 rounds
# [600]	training's l2: 0.344525	valid_1's l2: 0.399356
# [650]	training's l2: 0.332434	valid_1's l2: 0.388828
# [700]	training's l2: 0.325043	valid_1's l2: 0.386064
# [750]	training's l2: 0.319099	valid_1's l2: 0.385658
# [800]	training's l2: 0.313979	valid_1's l2: 0.385562
# [850]	training's l2: 0.309195	valid_1's l2: 0.385859
# [900]	training's l2: 0.304805	valid_1's l2: 0.385935
# Early stopping, best iteration is:
# [780]	training's l2: 0.315999	valid_1's l2: 0.385543
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.325841	valid_1's l2: 0.406365
# [1000]	training's l2: 0.315184	valid_1's l2: 0.419178
# Early stopping, best iteration is:
# [906]	training's l2: 0.350069	valid_1's l2: 0.38639
# Training until validation scores don't improve for 125 rounds
# [1050]	training's l2: 0.330049	valid_1's l2: 0.419183
# [1100]	training's l2: 0.319372	valid_1's l2: 0.415536
# [1150]	training's l2: 0.312318	valid_1's l2: 0.414082
# [1200]	training's l2: 0.306634	valid_1's l2: 0.413738
# [1250]	training's l2: 0.301665	valid_1's l2: 0.413761
# [1300]	training's l2: 0.297057	valid_1's l2: 0.414194
# Early stopping, best iteration is:
# [1214]	training's l2: 0.305208	valid_1's l2: 0.413639
# Training until validation scores don't improve for 125 rounds
# [1350]	training's l2: 0.331229	valid_1's l2: 0.412981
# [1400]	training's l2: 0.320892	valid_1's l2: 0.410113
# [1450]	training's l2: 0.313733	valid_1's l2: 0.409355
# [1500]	training's l2: 0.307919	valid_1's l2: 0.409344
# [1550]	training's l2: 0.302847	valid_1's l2: 0.409665
# [1600]	training's l2: 0.298096	valid_1's l2: 0.40993
# Early stopping, best iteration is:
# [1490]	training's l2: 0.308994	valid_1's l2: 0.409327
#
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.432193	valid_1's l2: 0.533886
# [100]	training's l2: 0.329257	valid_1's l2: 0.418813
# [150]	training's l2: 0.306746	valid_1's l2: 0.396116
# [200]	training's l2: 0.296384	valid_1's l2: 0.390554
# [250]	training's l2: 0.288497	valid_1's l2: 0.388999
# [300]	training's l2: 0.28292	valid_1's l2: 0.388856
# [350]	training's l2: 0.278136	valid_1's l2: 0.388829
# [400]	training's l2: 0.273904	valid_1's l2: 0.388626
# [450]	training's l2: 0.270031	valid_1's l2: 0.388978
# [500]	training's l2: 0.266417	valid_1's l2: 0.389193
# Early stopping, best iteration is:
# [397]	training's l2: 0.274153	valid_1's l2: 0.388611
# Training until validation scores don't improve for 125 rounds
# [550]	training's l2: 0.314081	valid_1's l2: 0.391017
# [600]	training's l2: 0.303971	valid_1's l2: 0.393818
# Early stopping, best iteration is:
# [523]	training's l2: 0.323626	valid_1's l2: 0.389345
# Training until validation scores don't improve for 125 rounds
# [650]	training's l2: 0.340392	valid_1's l2: 0.393683
# [700]	training's l2: 0.320751	valid_1's l2: 0.371272
# [750]	training's l2: 0.310818	valid_1's l2: 0.365904
# [800]	training's l2: 0.303921	valid_1's l2: 0.36421
# [850]	training's l2: 0.298368	valid_1's l2: 0.363977
# [900]	training's l2: 0.293448	valid_1's l2: 0.363872
# [950]	training's l2: 0.288993	valid_1's l2: 0.363972
# [1000]	training's l2: 0.28482	valid_1's l2: 0.364191
# Early stopping, best iteration is:
# [888]	training's l2: 0.294564	valid_1's l2: 0.363746
# Training until validation scores don't improve for 125 rounds
# [1050]	training's l2: 0.313752	valid_1's l2: 0.375209
# [1100]	training's l2: 0.303745	valid_1's l2: 0.383271
# Early stopping, best iteration is:
# [1014]	training's l2: 0.328171	valid_1's l2: 0.364592
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.322566	valid_1's l2: 0.383387
# [1200]	training's l2: 0.309954	valid_1's l2: 0.378019
# [1250]	training's l2: 0.30282	valid_1's l2: 0.37685
# [1300]	training's l2: 0.297392	valid_1's l2: 0.376583
# [1350]	training's l2: 0.292476	valid_1's l2: 0.376546
# [1400]	training's l2: 0.287984	valid_1's l2: 0.37673
# [1450]	training's l2: 0.283974	valid_1's l2: 0.376867
# Early stopping, best iteration is:
# [1325]	training's l2: 0.294857	valid_1's l2: 0.3764
# Training until validation scores don't improve for 125 rounds
# [1500]	training's l2: 0.307368	valid_1's l2: 0.378349
# [1550]	training's l2: 0.299815	valid_1's l2: 0.379994
# Early stopping, best iteration is:
# [1455]	training's l2: 0.316905	valid_1's l2: 0.37688
#
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.419843	valid_1's l2: 0.49645
# [100]	training's l2: 0.335862	valid_1's l2: 0.404571
# [150]	training's l2: 0.316285	valid_1's l2: 0.387125
# [200]	training's l2: 0.306605	valid_1's l2: 0.383389
# [250]	training's l2: 0.299071	valid_1's l2: 0.382376
# [300]	training's l2: 0.293094	valid_1's l2: 0.382827
# [350]	training's l2: 0.288245	valid_1's l2: 0.382992
# Early stopping, best iteration is:
# [247]	training's l2: 0.29948	valid_1's l2: 0.382285
# Training until validation scores don't improve for 125 rounds
# [400]	training's l2: 0.323057	valid_1's l2: 0.382939
# [450]	training's l2: 0.312708	valid_1's l2: 0.382803
# [500]	training's l2: 0.305326	valid_1's l2: 0.383223
# [550]	training's l2: 0.299401	valid_1's l2: 0.384227
# Early stopping, best iteration is:
# [458]	training's l2: 0.3114	valid_1's l2: 0.382729
# Training until validation scores don't improve for 125 rounds
# [600]	training's l2: 0.342426	valid_1's l2: 0.376906
# [650]	training's l2: 0.328637	valid_1's l2: 0.368495
# [700]	training's l2: 0.320371	valid_1's l2: 0.366043
# [750]	training's l2: 0.314093	valid_1's l2: 0.365103
# [800]	training's l2: 0.308472	valid_1's l2: 0.364749
# [850]	training's l2: 0.303453	valid_1's l2: 0.364595
# [900]	training's l2: 0.29877	valid_1's l2: 0.36464
# [950]	training's l2: 0.294509	valid_1's l2: 0.364781
# Early stopping, best iteration is:
# [845]	training's l2: 0.303929	valid_1's l2: 0.364591
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.330875	valid_1's l2: 0.369437
# [1050]	training's l2: 0.319647	valid_1's l2: 0.375192
# Early stopping, best iteration is:
# [971]	training's l2: 0.34405	valid_1's l2: 0.364906
# Training until validation scores don't improve for 125 rounds
# [1100]	training's l2: 0.342338	valid_1's l2: 0.376254
# [1150]	training's l2: 0.327609	valid_1's l2: 0.366893
# [1200]	training's l2: 0.318722	valid_1's l2: 0.364923
# [1250]	training's l2: 0.312197	valid_1's l2: 0.364365
# [1300]	training's l2: 0.306573	valid_1's l2: 0.364338
# [1350]	training's l2: 0.30164	valid_1's l2: 0.364317
# [1400]	training's l2: 0.297095	valid_1's l2: 0.364688
# Early stopping, best iteration is:
# [1294]	training's l2: 0.307205	valid_1's l2: 0.364311
# Training until validation scores don't improve for 125 rounds
# [1450]	training's l2: 0.331255	valid_1's l2: 0.365984
# [1500]	training's l2: 0.321461	valid_1's l2: 0.367335
# Early stopping, best iteration is:
# [1420]	training's l2: 0.340319	valid_1's l2: 0.364662
#
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.446642	valid_1's l2: 0.491745
# [100]	training's l2: 0.345354	valid_1's l2: 0.390843
# [150]	training's l2: 0.32149	valid_1's l2: 0.37227
# [200]	training's l2: 0.310249	valid_1's l2: 0.36816
# [250]	training's l2: 0.301564	valid_1's l2: 0.366326
# [300]	training's l2: 0.29526	valid_1's l2: 0.365641
# [350]	training's l2: 0.290093	valid_1's l2: 0.365661
# [400]	training's l2: 0.28565	valid_1's l2: 0.365557
# [450]	training's l2: 0.281486	valid_1's l2: 0.365664
# [500]	training's l2: 0.277641	valid_1's l2: 0.365666
# Early stopping, best iteration is:
# [405]	training's l2: 0.285231	valid_1's l2: 0.365513
# Training until validation scores don't improve for 125 rounds
# [550]	training's l2: 0.325891	valid_1's l2: 0.363347
# [600]	training's l2: 0.314213	valid_1's l2: 0.361471
# [650]	training's l2: 0.307022	valid_1's l2: 0.360862
# [700]	training's l2: 0.30119	valid_1's l2: 0.360764
# [750]	training's l2: 0.295982	valid_1's l2: 0.360528
# [800]	training's l2: 0.291188	valid_1's l2: 0.360584
# [850]	training's l2: 0.286806	valid_1's l2: 0.360516
# [900]	training's l2: 0.282702	valid_1's l2: 0.360715
# [950]	training's l2: 0.278863	valid_1's l2: 0.360805
# Early stopping, best iteration is:
# [842]	training's l2: 0.287516	valid_1's l2: 0.360468
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.329408	valid_1's l2: 0.3584
# [1050]	training's l2: 0.319688	valid_1's l2: 0.35767
# [1100]	training's l2: 0.312849	valid_1's l2: 0.357355
# [1150]	training's l2: 0.306854	valid_1's l2: 0.357296
# [1200]	training's l2: 0.301622	valid_1's l2: 0.357339
# [1250]	training's l2: 0.296836	valid_1's l2: 0.357484
# Early stopping, best iteration is:
# [1151]	training's l2: 0.306743	valid_1's l2: 0.357279
# Training until validation scores don't improve for 125 rounds
# [1300]	training's l2: 0.332862	valid_1's l2: 0.359072
# [1350]	training's l2: 0.320244	valid_1's l2: 0.361989
# [1400]	training's l2: 0.312626	valid_1's l2: 0.363628
# Early stopping, best iteration is:
# [1277]	training's l2: 0.343575	valid_1's l2: 0.357585
# Training until validation scores don't improve for 125 rounds
# [1450]	training's l2: 0.322567	valid_1's l2: 0.358944
# [1500]	training's l2: 0.314039	valid_1's l2: 0.357988
# [1550]	training's l2: 0.307812	valid_1's l2: 0.357645
# [1600]	training's l2: 0.302528	valid_1's l2: 0.357478
# [1650]	training's l2: 0.297791	valid_1's l2: 0.357621
# [1700]	training's l2: 0.293345	valid_1's l2: 0.357787
# Early stopping, best iteration is:
# [1583]	training's l2: 0.3043	valid_1's l2: 0.357441
# Training until validation scores don't improve for 125 rounds
# [1750]	training's l2: 0.338272	valid_1's l2: 0.354922
# [1800]	training's l2: 0.327313	valid_1's l2: 0.353967
# [1850]	training's l2: 0.319718	valid_1's l2: 0.353973
# [1900]	training's l2: 0.313535	valid_1's l2: 0.353948
# [1950]	training's l2: 0.308165	valid_1's l2: 0.354091
# Early stopping, best iteration is:
# [1833]	training's l2: 0.322072	valid_1's l2: 0.353836
#
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.479089	valid_1's l2: 0.497779
# [100]	training's l2: 0.366366	valid_1's l2: 0.394782
# [150]	training's l2: 0.340461	valid_1's l2: 0.378113
# [200]	training's l2: 0.328034	valid_1's l2: 0.37434
# [250]	training's l2: 0.318636	valid_1's l2: 0.373376
# [300]	training's l2: 0.311426	valid_1's l2: 0.372986
# [350]	training's l2: 0.305454	valid_1's l2: 0.373303
# [400]	training's l2: 0.300531	valid_1's l2: 0.373545
# Early stopping, best iteration is:
# [299]	training's l2: 0.311526	valid_1's l2: 0.372973
# Training until validation scores don't improve for 125 rounds
# [450]	training's l2: 0.372279	valid_1's l2: 0.366648
# [500]	training's l2: 0.345232	valid_1's l2: 0.369917
# [550]	training's l2: 0.333679	valid_1's l2: 0.372717
# Early stopping, best iteration is:
# [450]	training's l2: 0.372279	valid_1's l2: 0.366648
# Training until validation scores don't improve for 125 rounds
# [600]	training's l2: 0.356468	valid_1's l2: 0.367051
# [650]	training's l2: 0.340818	valid_1's l2: 0.364239
# [700]	training's l2: 0.331658	valid_1's l2: 0.364145
# [750]	training's l2: 0.32471	valid_1's l2: 0.364349
# [800]	training's l2: 0.318692	valid_1's l2: 0.36448
# Early stopping, best iteration is:
# [675]	training's l2: 0.335885	valid_1's l2: 0.364053
# Training until validation scores don't improve for 125 rounds
# [850]	training's l2: 0.343304	valid_1's l2: 0.367756
# [900]	training's l2: 0.332405	valid_1's l2: 0.36993
# Early stopping, best iteration is:
# [801]	training's l2: 0.363169	valid_1's l2: 0.364519
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.34805	valid_1's l2: 0.369437
# [1000]	training's l2: 0.336031	valid_1's l2: 0.370353
# [1050]	training's l2: 0.327687	valid_1's l2: 0.371084
# Early stopping, best iteration is:
# [949]	training's l2: 0.348456	valid_1's l2: 0.369427
# Training until validation scores don't improve for 125 rounds
# [1100]	training's l2: 0.358164	valid_1's l2: 0.36637
# [1150]	training's l2: 0.344211	valid_1's l2: 0.36305
# [1200]	training's l2: 0.335045	valid_1's l2: 0.362261
# [1250]	training's l2: 0.327967	valid_1's l2: 0.362036
# [1300]	training's l2: 0.322166	valid_1's l2: 0.361972
# [1350]	training's l2: 0.316928	valid_1's l2: 0.362058
# [1400]	training's l2: 0.312081	valid_1's l2: 0.362036
# Early stopping, best iteration is:
# [1318]	training's l2: 0.320213	valid_1's l2: 0.36189
#
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.500069	valid_1's l2: 0.515211
# [100]	training's l2: 0.376531	valid_1's l2: 0.406477
# [150]	training's l2: 0.348309	valid_1's l2: 0.38892
# [200]	training's l2: 0.334567	valid_1's l2: 0.384957
# [250]	training's l2: 0.324051	valid_1's l2: 0.383399
# [300]	training's l2: 0.316185	valid_1's l2: 0.382831
# [350]	training's l2: 0.310064	valid_1's l2: 0.382883
# [400]	training's l2: 0.304827	valid_1's l2: 0.382999
# Early stopping, best iteration is:
# [296]	training's l2: 0.316709	valid_1's l2: 0.382793
# Training until validation scores don't improve for 125 rounds
# [450]	training's l2: 0.379227	valid_1's l2: 0.379047
# [500]	training's l2: 0.354791	valid_1's l2: 0.383559
# [550]	training's l2: 0.343273	valid_1's l2: 0.385731
# Early stopping, best iteration is:
# [446]	training's l2: 0.38263	valid_1's l2: 0.378909
# Training until validation scores don't improve for 125 rounds
# [600]	training's l2: 0.356883	valid_1's l2: 0.378247
# [650]	training's l2: 0.342337	valid_1's l2: 0.374712
# [700]	training's l2: 0.332798	valid_1's l2: 0.373892
# [750]	training's l2: 0.325174	valid_1's l2: 0.373831
# [800]	training's l2: 0.31894	valid_1's l2: 0.373958
# [850]	training's l2: 0.313334	valid_1's l2: 0.374048
# Early stopping, best iteration is:
# [758]	training's l2: 0.32411	valid_1's l2: 0.373764
# Training until validation scores don't improve for 125 rounds
# [900]	training's l2: 0.362386	valid_1's l2: 0.37351
# [950]	training's l2: 0.346065	valid_1's l2: 0.374549
# [1000]	training's l2: 0.336843	valid_1's l2: 0.375417
# Early stopping, best iteration is:
# [900]	training's l2: 0.362386	valid_1's l2: 0.37351
# Training until validation scores don't improve for 125 rounds
# [1050]	training's l2: 0.350851	valid_1's l2: 0.375831
# [1100]	training's l2: 0.33766	valid_1's l2: 0.378387
# [1150]	training's l2: 0.328707	valid_1's l2: 0.38061
# Early stopping, best iteration is:
# [1038]	training's l2: 0.355759	valid_1's l2: 0.375379
# Training until validation scores don't improve for 125 rounds
# [1200]	training's l2: 0.353503	valid_1's l2: 0.374064
# [1250]	training's l2: 0.341555	valid_1's l2: 0.371211
# [1300]	training's l2: 0.332766	valid_1's l2: 0.370574
# [1350]	training's l2: 0.326192	valid_1's l2: 0.370093
# [1400]	training's l2: 0.320477	valid_1's l2: 0.369828
# [1450]	training's l2: 0.315278	valid_1's l2: 0.369819
# [1500]	training's l2: 0.310493	valid_1's l2: 0.369737
# [1550]	training's l2: 0.306051	valid_1's l2: 0.369782
# [1600]	training's l2: 0.301856	valid_1's l2: 0.369696
# [1650]	training's l2: 0.297775	valid_1's l2: 0.369833
# [1700]	training's l2: 0.293958	valid_1's l2: 0.369814
# Early stopping, best iteration is:
# [1599]	training's l2: 0.301934	valid_1's l2: 0.369674
#
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.459929	valid_1's l2: 0.492572
# [100]	training's l2: 0.363405	valid_1's l2: 0.399388
# [150]	training's l2: 0.340447	valid_1's l2: 0.38361
# [200]	training's l2: 0.328911	valid_1's l2: 0.380472
# [250]	training's l2: 0.31999	valid_1's l2: 0.379894
# [300]	training's l2: 0.313401	valid_1's l2: 0.379543
# [350]	training's l2: 0.307836	valid_1's l2: 0.379611
# [400]	training's l2: 0.302978	valid_1's l2: 0.3799
# Early stopping, best iteration is:
# [301]	training's l2: 0.313255	valid_1's l2: 0.379518
# Training until validation scores don't improve for 125 rounds
# [450]	training's l2: 0.386486	valid_1's l2: 0.373078
# [500]	training's l2: 0.362553	valid_1's l2: 0.372807
# [550]	training's l2: 0.351332	valid_1's l2: 0.374325
# Early stopping, best iteration is:
# [474]	training's l2: 0.372044	valid_1's l2: 0.372011
# [600]	training's l2: 0.363924	valid_1's l2: 0.374581
# Training until validation scores don't improve for 125 rounds
# [650]	training's l2: 0.345587	valid_1's l2: 0.371904
# [700]	training's l2: 0.335473	valid_1's l2: 0.371786
# [750]	training's l2: 0.327961	valid_1's l2: 0.372121
# [800]	training's l2: 0.321657	valid_1's l2: 0.372357
# Early stopping, best iteration is:
# [688]	training's l2: 0.337586	valid_1's l2: 0.371736
# Training until validation scores don't improve for 125 rounds
# [850]	training's l2: 0.352119	valid_1's l2: 0.371586
# [900]	training's l2: 0.341663	valid_1's l2: 0.371972
# [950]	training's l2: 0.334276	valid_1's l2: 0.372361
# Early stopping, best iteration is:
# [855]	training's l2: 0.350664	valid_1's l2: 0.371518
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.3644	valid_1's l2: 0.372157
# [1050]	training's l2: 0.350949	valid_1's l2: 0.373372
# [1100]	training's l2: 0.341699	valid_1's l2: 0.374581
# Early stopping, best iteration is:
# [994]	training's l2: 0.366722	valid_1's l2: 0.372054
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.35893	valid_1's l2: 0.372139
# [1200]	training's l2: 0.345882	valid_1's l2: 0.370719
# [1250]	training's l2: 0.336838	valid_1's l2: 0.370182
# [1300]	training's l2: 0.329697	valid_1's l2: 0.36966
# [1350]	training's l2: 0.32383	valid_1's l2: 0.369453
# [1400]	training's l2: 0.318563	valid_1's l2: 0.36923
# [1450]	training's l2: 0.313708	valid_1's l2: 0.36902
# [1500]	training's l2: 0.309138	valid_1's l2: 0.368934
# [1550]	training's l2: 0.304902	valid_1's l2: 0.369
# [1600]	training's l2: 0.300808	valid_1's l2: 0.36902
# Early stopping, best iteration is:
# [1500]	training's l2: 0.309138	valid_1's l2: 0.368934
#
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.438869	valid_1's l2: 0.471543
# [100]	training's l2: 0.346786	valid_1's l2: 0.383347
# [150]	training's l2: 0.324445	valid_1's l2: 0.368454
# [200]	training's l2: 0.31342	valid_1's l2: 0.365226
# [250]	training's l2: 0.305202	valid_1's l2: 0.364899
# [300]	training's l2: 0.299192	valid_1's l2: 0.364687
# [350]	training's l2: 0.293934	valid_1's l2: 0.364808
# [400]	training's l2: 0.289368	valid_1's l2: 0.365092
# [450]	training's l2: 0.285102	valid_1's l2: 0.365351
# Early stopping, best iteration is:
# [325]	training's l2: 0.296444	valid_1's l2: 0.364591
# Training until validation scores don't improve for 125 rounds
# [500]	training's l2: 0.358702	valid_1's l2: 0.35731
# [550]	training's l2: 0.344944	valid_1's l2: 0.358363
# [600]	training's l2: 0.336572	valid_1's l2: 0.359225
# Early stopping, best iteration is:
# [496]	training's l2: 0.360395	valid_1's l2: 0.35723
# Training until validation scores don't improve for 125 rounds
# [650]	training's l2: 0.34088	valid_1's l2: 0.356786
# [700]	training's l2: 0.328913	valid_1's l2: 0.356439
# [750]	training's l2: 0.321429	valid_1's l2: 0.356729
# [800]	training's l2: 0.315046	valid_1's l2: 0.356748
# Early stopping, best iteration is:
# [682]	training's l2: 0.332501	valid_1's l2: 0.35635
# Training until validation scores don't improve for 125 rounds
# [850]	training's l2: 0.336469	valid_1's l2: 0.357339
# [900]	training's l2: 0.32741	valid_1's l2: 0.358396
# Early stopping, best iteration is:
# [812]	training's l2: 0.349194	valid_1's l2: 0.356542
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.350459	valid_1's l2: 0.358051
# [1000]	training's l2: 0.337132	valid_1's l2: 0.357281
# [1050]	training's l2: 0.327975	valid_1's l2: 0.357207
# [1100]	training's l2: 0.321142	valid_1's l2: 0.35745
# Early stopping, best iteration is:
# [1013]	training's l2: 0.334349	valid_1's l2: 0.357125
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.409561	valid_1's l2: 0.356893
# [1200]	training's l2: 0.369186	valid_1's l2: 0.369636
# [1250]	training's l2: 0.353521	valid_1's l2: 0.379308
# Early stopping, best iteration is:
# [1144]	training's l2: 0.41955	valid_1's l2: 0.356666
#
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.440389	valid_1's l2: 0.459965
# [100]	training's l2: 0.341024	valid_1's l2: 0.368611
# [150]	training's l2: 0.31772	valid_1's l2: 0.352855
# [200]	training's l2: 0.306673	valid_1's l2: 0.349334
# [250]	training's l2: 0.298057	valid_1's l2: 0.347998
# [300]	training's l2: 0.291795	valid_1's l2: 0.347793
# [350]	training's l2: 0.286736	valid_1's l2: 0.347914
# [400]	training's l2: 0.282188	valid_1's l2: 0.348051
# Early stopping, best iteration is:
# [285]	training's l2: 0.293531	valid_1's l2: 0.347741
# Training until validation scores don't improve for 125 rounds
# [450]	training's l2: 0.338794	valid_1's l2: 0.342461
# [500]	training's l2: 0.326252	valid_1's l2: 0.342221
# [550]	training's l2: 0.317756	valid_1's l2: 0.342653
# Early stopping, best iteration is:
# [467]	training's l2: 0.333725	valid_1's l2: 0.342156
# Training until validation scores don't improve for 125 rounds
# [600]	training's l2: 0.333408	valid_1's l2: 0.341934
# [650]	training's l2: 0.320448	valid_1's l2: 0.34054
# [700]	training's l2: 0.312079	valid_1's l2: 0.34053
# [750]	training's l2: 0.305635	valid_1's l2: 0.340473
# [800]	training's l2: 0.300098	valid_1's l2: 0.340633
# [850]	training's l2: 0.295148	valid_1's l2: 0.340687
# Early stopping, best iteration is:
# [743]	training's l2: 0.306459	valid_1's l2: 0.340431
# Training until validation scores don't improve for 125 rounds
# [900]	training's l2: 0.328025	valid_1's l2: 0.341036
# [950]	training's l2: 0.317569	valid_1's l2: 0.341607
# Early stopping, best iteration is:
# [873]	training's l2: 0.338079	valid_1's l2: 0.340632
# Training until validation scores don't improve for 125 rounds
# [1000]	training's l2: 0.336919	valid_1's l2: 0.341739
# [1050]	training's l2: 0.322738	valid_1's l2: 0.341584
# [1100]	training's l2: 0.313397	valid_1's l2: 0.342101
# Early stopping, best iteration is:
# [1021]	training's l2: 0.329662	valid_1's l2: 0.341225
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.395388	valid_1's l2: 0.341415
# [1200]	training's l2: 0.349985	valid_1's l2: 0.346318
# [1250]	training's l2: 0.335789	valid_1's l2: 0.353067
# Early stopping, best iteration is:
# [1160]	training's l2: 0.380306	valid_1's l2: 0.340512
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 125 rounds
# [50]	training's l2: 0.428263	valid_1's l2: 0.466181
# [100]	training's l2: 0.343478	valid_1's l2: 0.388548
# [150]	training's l2: 0.322929	valid_1's l2: 0.375358
# [200]	training's l2: 0.312265	valid_1's l2: 0.372904
# [250]	training's l2: 0.304018	valid_1's l2: 0.372222
# [300]	training's l2: 0.297877	valid_1's l2: 0.372485
# [350]	training's l2: 0.292794	valid_1's l2: 0.372626
# Early stopping, best iteration is:
# [242]	training's l2: 0.30521	valid_1's l2: 0.372158
# Training until validation scores don't improve for 125 rounds
# [400]	training's l2: 0.349719	valid_1's l2: 0.367507
# [450]	training's l2: 0.337365	valid_1's l2: 0.366054
# [500]	training's l2: 0.329124	valid_1's l2: 0.365871
# [550]	training's l2: 0.322248	valid_1's l2: 0.365953
# [600]	training's l2: 0.316583	valid_1's l2: 0.366045
# Early stopping, best iteration is:
# [492]	training's l2: 0.33033	valid_1's l2: 0.365847
# Training until validation scores don't improve for 125 rounds
# [650]	training's l2: 0.341584	valid_1's l2: 0.365775
# [700]	training's l2: 0.329526	valid_1's l2: 0.366552
# [750]	training's l2: 0.321679	valid_1's l2: 0.366983
# Early stopping, best iteration is:
# [643]	training's l2: 0.343903	valid_1's l2: 0.365586
# Training until validation scores don't improve for 125 rounds
# [800]	training's l2: 0.343537	valid_1's l2: 0.365431
# [850]	training's l2: 0.332012	valid_1's l2: 0.365559
# [900]	training's l2: 0.323822	valid_1's l2: 0.365955
# Early stopping, best iteration is:
# [815]	training's l2: 0.339739	valid_1's l2: 0.365199
# Training until validation scores don't improve for 125 rounds
# [950]	training's l2: 0.352562	valid_1's l2: 0.365814
# [1000]	training's l2: 0.337311	valid_1's l2: 0.365681
# [1050]	training's l2: 0.327976	valid_1's l2: 0.366211
# [1100]	training's l2: 0.320935	valid_1's l2: 0.36665
# Early stopping, best iteration is:
# [975]	training's l2: 0.34385	valid_1's l2: 0.36552
# Training until validation scores don't improve for 125 rounds
# [1150]	training's l2: 0.35472	valid_1's l2: 0.362923
# [1200]	training's l2: 0.342498	valid_1's l2: 0.363884
# [1250]	training's l2: 0.334266	valid_1's l2: 0.364498
# Early stopping, best iteration is:
# [1135]	training's l2: 0.360193	valid_1's l2: 0.362745

# %%
# cross validation output

print("Validation mse:", mean_squared_error(
    y_val, np.array(val_pred).transpose()))

weight = items["perishable"] * 0.25 + 1
err = (y_val - np.array(val_pred).transpose())**2
err = err.sum(axis=1) * weight
err = np.sqrt(err.sum() / weight.sum() / 16)
print('nwrmsle = {}'.format(err))

y_val = np.array(val_pred).transpose()
df_preds = pd.DataFrame(
    y_val, index=df_2017.index,
    columns=pd.date_range("2017-07-26", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)
df_preds["unit_sales"] = np.clip(np.expm1(df_preds["unit_sales"]), 0, 1000)
df_preds.reset_index().to_csv('lgb_cv.csv', index=False)
# Out:
# Validation mse: 0.3520074451285224
# nwrmsle = 0.5931245655523382

# %%
# submit prediction

print("Making submission...")
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(
    y_test, index=df_2017.index,
    columns=pd.date_range("2017-08-16", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)

submission = df_test[["id"]].join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv('lgb_sub.csv', float_format='%.4f', index=None)
# Out:
# Making submission...
